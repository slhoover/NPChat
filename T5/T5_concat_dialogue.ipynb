# %%
 # Installing
# !pip install pydot --quiet
# !pip install gensim==3.8.3 --quiet
# !pip install tensorflow-datasets --quiet
# !pip install -U tensorflow-text==2.12.0 --quiet
# !pip install transformers --quiet
# !pip install -q sentencepiece
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 19.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for gensim (setup.py) ... error
#   ERROR: Failed building wheel for gensim
# ERROR: Could not build wheels for gensim, which is required to install pyproject.toml-based projects
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 44.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 51.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.1/311.1 kB 30.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 54.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 24.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.6 MB/s eta 0:00:00

# %%
#@title Installs

# !pip install datasets --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.9 MB/s eta 0:00:00

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.layers import Embedding, Input, Dense, Lambda
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K
import tensorflow_hub as hub
#import tensorflow_datasets as tfds
#import tensorflow_text as tf_text


from transformers import T5Tokenizer, TFT5Model, TFT5ForConditionalGeneration, TFAutoModelForSequenceClassification

import sklearn as sk
import os
import nltk
from nltk.data import find

import matplotlib.pyplot as plt
import transformers

import re

#This continues to work with gensim 3.8.3.  It doesn't yet work with 4.x.
#Make sure your pip install command specifies gensim==3.8.3
import gensim

# %%
try:
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
  print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
except ValueError:
  raise BaseException('ERROR: Not connected to a TPU runtime; please see the previous cell in this notebook for instructions!')

tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
tpu_strategy = tf.distribute.TPUStrategy(tpu)
# Out:
# Running on TPU  ['10.12.92.146:8470']

# %%
#@title Loading dataset

# Load the dataset
from datasets import load_dataset
import pandas as pd
npc_train = load_dataset("amaydle/npc-dialogue", split="train")
npc_test = load_dataset("amaydle/npc-dialogue", split="test")

# Automatically splits it into train and test for you - let's ignore that for now and just combine them as one

# First, transform them into pandas DFs
train = pd.DataFrame(data = {'name': npc_train['Name'], 'bio':npc_train['Biography'], 'query':npc_train['Query'], 'response':npc_train['Response'], 'emotion':npc_train['Emotion']})
test = pd.DataFrame(data = {'name': npc_test['Name'], 'bio':npc_test['Biography'], 'query':npc_test['Query'], 'response':npc_test['Response'], 'emotion':npc_test['Emotion']})



# Just use the training dataset for now
# npc = pd.concat([train, test])
# Out:
# Downloading readme:   0%|          | 0.00/579 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/166k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/35.7k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/1723 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/192 [00:00<?, ? examples/s]

# %%
train['query'] = 'question: ' + train['query']
train['response'] = 'response: ' + train['response']
train['dialogue'] = train['query'] + ' ' + train['response']
train = train.groupby(['name', 'bio'])['dialogue'].apply(lambda x: ' '.join(x)).reset_index()
train['last_response_index'] = train['dialogue'].apply(lambda x: x.rfind('response: '))

def subset_str(my_string, my_index):
  return my_string[my_index:]

def remove_last_response(my_string, my_index):
  return my_string[:my_index]

train['last_response'] = train[['dialogue', 'last_response_index']].apply(lambda x: subset_str(*x), axis=1)
train['dialogue'] = train[['dialogue', 'last_response_index']].apply(lambda x: remove_last_response(*x), axis=1)

# %%
test['query'] = 'question: ' + test['query']
test['response'] = 'response: ' + test['response']
test['dialogue'] = test['query'] + ' ' + test['response']
test = test.groupby(['name', 'bio'])['dialogue'].apply(lambda x: ' '.join(x)).reset_index()
test['last_response_index'] = test['dialogue'].apply(lambda x: x.rfind('response: '))

test['last_response'] = test[['dialogue', 'last_response_index']].apply(lambda x: subset_str(*x), axis=1)
test['dialogue'] = test[['dialogue', 'last_response_index']].apply(lambda x: remove_last_response(*x), axis=1)
test
# Out:
#                       name                                                bio  \
# 0      Adalyn the Huntress  Adalyn is a fearless and skilled hunter from t...
# 1                 Agent 47  Agent 47 is a genetically engineered assassin,...
# 2              Aiden Stone  Aiden is a skilled thief who grew up on the st...
# 3   Alistair the Enchanter  Alistair is a powerful wizard who lived in the...
# 4                   Althea  Althea is a half-elf ranger with a fierce inde...
# ..                     ...                                                ...
# 79                Vincenzo  Vincenzo is a cunning and charismatic thief, w...
# 80        Wednesday Addams  Wednesday Addams is a teenage goth and the dau...
# 81          Zara the Brave  Zara was born in a small village, but her curi...
# 82                  Zephyr  Zephyr is a mischievous fairy who loves playin...
# 83                    Zuko  Zuko is a former prince of the Fire Nation and...
#
#                                              dialogue  last_response_index  \
# 0   question: Do you have any hunting techniques t...                  246
# 1   question: How did Agent 47 become an assassin?...                  152
# 2   question: "How do you feel about people who un...                  206
# 3   question: Have you ever been betrayed by someo...                   63
# 4   question: Althea, have you ever faced a danger...                 1004
# ..                                                ...                  ...
# 79  question: What is your greatest accomplishment...                  137
# 80  question: What is your opinion on love? respon...                  344
# 81  question: What motivates Zara to keep fighting...                  559
# 82  question: What motivates you to play pranks on...                  524
# 83  question: What is your favorite thing to do? r...                  154
#
#                                         last_response
# 0   response: No, I do not regret any of my hunts....
# 1                    response: Not that I'm aware of.
# 2   response: "The most important lesson I've lear...
# 3   response: Yes, but learned to forgive and move...
# 4   response: (Pauses) There have been a few times...
# ..                                                ...
# 79            response: "Honesty, for fools, not me."
# 80    response: "Justice, important, must be served."
# 81  response: Zara believes that the kingdom is in...
# 82  response: Yes, I have. It was a difficult expe...
# 83  response: My perseverance and determination to...
#
# [84 rows x 5 columns]

# %% [markdown]
# Data Preparation

# %%
# Pre-processing steps of the input claim for T5 classification task

def prep_for_t5(input):
  # pre-pend the data with the task: since we're not using one of T5's built in tasks we can just make up our own (this step is optional)
  input = 'dialogue: ' + input
  return input

# Apply to the dataset - using the combined text that uses other metadata as well (such as the bio)
def concatenate_input(df):
  df['input'] = df['name'] + ' ' + df['bio'] + ' ' + df['dialogue']
  return df

#train = concatenate_input(train)
train = concatenate_input(train)
train['input'] = train['input'].apply(lambda x: prep_for_t5(x))
#test = concatenate_input(test)
test = concatenate_input(test)
test['input'] = test['input'].apply(lambda x: prep_for_t5(x))

train
# Out:
#                        name  \
# 0       Adalyn the Huntress
# 1                  Agent 47
# 2               Aiden Stone
# 3    Alistair the Enchanter
# 4                    Althea
# ..                      ...
# 97                 Vincenzo
# 98         Wednesday Addams
# 99           Zara the Brave
# 100                  Zephyr
# 101                    Zuko
#
#                                                    bio  \
# 0    Adalyn is a fearless and skilled hunter from t...
# 1    Agent 47 is a genetically engineered assassin,...
# 2    Aiden is a skilled thief who grew up on the st...
# 3    Alistair is a powerful wizard who lived in the...
# 4    Althea is a half-elf ranger with a fierce inde...
# ..                                                 ...
# 97   Vincenzo is a cunning and charismatic thief, w...
# 98   Wednesday Addams is a teenage goth and the dau...
# 99   Zara was born in a small village, but her curi...
# 100  Zephyr is a mischievous fairy who loves playin...
# 101  Zuko is a former prince of the Fire Nation and...
#
#                                               dialogue  last_response_index  \
# 0    question: Have you ever hunted in a different ...                 2589
# 1    question: Does Agent 47 have any allies? respo...                 1593
# 2    question: Can you tell me about the first time...                 3552
# 3    question: Can you tell me about a magical item...                 1727
# 4    question: Althea, have you ever been betrayed ...                 3470
# ..                                                 ...                  ...
# 97   question: What is your opinion on justice? res...                 1506
# 98   question: Have you ever felt scared? response:...                 1390
# 99   question: How does Zara feel about working wit...                 3996
# 100  question: Do you believe in true love? respons...                 3348
# 101  question: What is your favorite food? response...                 1947
#
#                                          last_response  \
# 0    response: I hunt all sorts of animals, from de...
# 1                        response: Not that I know of.
# 2    response: "I enjoy spending time in nature, an...
# 3    response: Encountered many, but dragons are my...
# 4    response: (Shudders) There was this one time I...
# ..                                                 ...
# 97          response: "No, steal from rich, not poor."
# 98             response: "Norms, boring, ignore them."
# 99   response: Zara doesn't have much free time, bu...
# 100  response: I don't really fear anything, to be ...
# 101  response: I was born into privilege, but it ca...
#
#                                                  input
# 0    dialogue: Adalyn the Huntress Adalyn is a fear...
# 1    dialogue: Agent 47 Agent 47 is a genetically e...
# 2    dialogue: Aiden Stone Aiden is a skilled thief...
# 3    dialogue: Alistair the Enchanter Alistair is a...
# 4    dialogue: Althea Althea is a half-elf ranger w...
# ..                                                 ...
# 97   dialogue: Vincenzo Vincenzo is a cunning and c...
# 98   dialogue: Wednesday Addams Wednesday Addams is...
# 99   dialogue: Zara the Brave Zara was born in a sm...
# 100  dialogue: Zephyr Zephyr is a mischievous fairy...
# 101  dialogue: Zuko Zuko is a former prince of the ...
#
# [102 rows x 6 columns]

# %%
train = train[['input', 'last_response']].rename(columns={'last_response':'response'})
train = train.to_dict('records')

test = test[['input', 'last_response']].rename(columns={'last_response':'response'})
test = test.to_dict('records')

# %%
train[0]
# Out:
# {'input': "dialogue: Adalyn the Huntress Adalyn is a fearless and skilled hunter from the forest. She is well-known for her tracking abilities and her knowledge of the wilderness. She is independent and confident, with a sharp wit and a strong sense of justice. question: Have you ever hunted in a different environment? response: Yes, I have hunted in many different environments, from forests to mountains to deserts. question: Do you hunt for sport or food? response: Both, but mostly for food. question: What do you like most about hunting? response: The thrill of the chase. question: Have you ever encountered a magical creature during your hunts? response: Yes, I've hunted enchanted deer and unicorns. question: Have you ever been injured while hunting? response: Yes, I have been injured many times. Hunting can be dangerous, but I always heal quickly. question: Why do you hunt? response: Hunting provides food and resources for my village, and it keeps me sharp and skilled. question: Do you have any hunting tips for new hunters? response: My best tip is to always be prepared and stay alert. Hunting can be dangerous, so it's important to be ready for anything. question: What is your favorite weapon for hunting? response: My favorite weapon for hunting is my bow. It is precise and silent, and it allows me to take down my prey quickly and efficiently. question: Have you ever hunted at night? response: Yes, I have hunted at night many times. Night hunting can be difficult, but it can also be very rewarding. question: Can you tell me about a particularly dangerous creature you've hunted? response: I once tracked and killed a fierce basilisk in the mountains. question: What do you do with the animals you catch? response: I bring the animals back to my village to be processed and used for food, clothing, and other resources. question: Have you ever hunted with a group of people? response: Yes, I have hunted with a group before. It can be helpful to have allies when hunting dangerous game. question: What is the most difficult animal you have ever hunted? response: The most difficult animal I have ever hunted was a dragon. It was a dangerous and difficult battle, but I emerged victorious. question: Can you tell me about your home and family? response: I come from a small village deep in the forest. I was raised by my father, who taught me everything I know about hunting and survival. question: What is your favorite animal to hunt? response: My favorite animal to hunt is the stag. They are graceful and fast, and a successful hunt is always a thrill. question: Have you ever been injured during a hunt? response: Of course, but I always heal quickly. question: What do you do when you're not hunting? response: I explore new territories and visit towns for supplies. question: What kind of animals do you like to hunt? ",
#  'response': 'response: I hunt all sorts of animals, from deer to wolves to bears.'}

# %%
# Encode the dataset
def encode(example,
           encoder_max_len, decoder_max_len):

    input = example['input']
    label = example['response']

    encoder_inputs = t5_tokenizer(input, return_tensors='tf', max_length=encoder_max_len, padding='max_length', truncation=True)

    decoder_inputs = t5_tokenizer(label, return_tensors='tf', max_length=decoder_max_len, padding='max_length', truncation=True)

    input_ids = encoder_inputs['input_ids'][0]
    input_attention = encoder_inputs['attention_mask'][0]
    target_ids = decoder_inputs['input_ids'][0]
    target_attention = decoder_inputs['attention_mask'][0]

    outputs = {'input_ids':input_ids, 'attention_mask': input_attention,
               'labels':target_ids, 'decoder_attention_mask':target_attention}
    return outputs

# %%
# organize the inputs as a dictionary to convert to a tf dataset
t5_tokenizer = T5Tokenizer.from_pretrained('t5-small')
ds = [encode(x, encoder_max_len = 512, decoder_max_len = 50) for x in train]
test_ds = [encode(x, encoder_max_len = 512, decoder_max_len = 50) for x in test]
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# Convert to tf dataset

# Code borrowed from https://colab.research.google.com/github/snapthat/TF-T5-text-to-text/blob/master/snapthatT5/notebooks/TF-T5-Datasets%20Training.ipynb#scrollTo=TJVLbHbelMki
# and drew inspiration from https://stackoverflow.com/questions/68567630/converting-a-list-of-dictionaries-to-a-tf-dataset
def to_tf_dataset(dataset):
  input_ids = tf.data.Dataset.from_tensor_slices([d['input_ids'] for d in dataset])
  input_attention = tf.data.Dataset.from_tensor_slices([d['attention_mask'] for d in dataset])
  labels = tf.data.Dataset.from_tensor_slices([d['labels'] for d in dataset])
  decoder_attention_mask = tf.data.Dataset.from_tensor_slices([d['decoder_attention_mask'] for d in dataset])
  ds = tf.data.Dataset.zip((input_ids, input_attention, labels, decoder_attention_mask))
  ds = ds.map(lambda x, y, z, l: {"input_ids": x, "attention_mask": y,
                                "labels": z, "decoder_attention_mask": l})
  return ds

# %%
# 4 datasets - train/test for six way and binary classification tasks
ds = ds[0:1722]
train_tf = to_tf_dataset(ds)
test_tf = to_tf_dataset(test_ds)

# %%
# compile the models
with tpu_strategy.scope(): # creating the model in the TPUStrategy scope means we will train the model on the TPU
#import T5 model (using small to minimize run time)

    # Batch the datasets
  def batch_dataset(dataset, batch_size=7):
    dataset = dataset.batch(batch_size)
    return dataset

  train_tf = batch_dataset(train_tf)
  test_tf = batch_dataset(test_tf)

  model = TFT5ForConditionalGeneration.from_pretrained('t5-small') # using small to prevent GPU from crashing
  learning_rate = 0.001
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFT5ForConditionalGeneration.
#
# All the weights of TFT5ForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.

# %%
# Fit the model - binary
history = model.fit(train_tf, epochs=25, validation_data = test_tf, batch_size=10)
# Out:
# Epoch 1/25
# 15/15 [==============================] - 96s 910ms/step - loss: nan - val_loss: nan
# Epoch 2/25
# 15/15 [==============================] - 3s 171ms/step - loss: nan - val_loss: nan
# Epoch 3/25
# 15/15 [==============================] - 3s 171ms/step - loss: nan - val_loss: nan
# Epoch 4/25
# 15/15 [==============================] - 2s 172ms/step - loss: nan - val_loss: nan
# Epoch 5/25
# 15/15 [==============================] - 3s 187ms/step - loss: nan - val_loss: nan
# Epoch 6/25
# 15/15 [==============================] - 3s 204ms/step - loss: nan - val_loss: nan
# Epoch 7/25
# 15/15 [==============================] - 4s 266ms/step - loss: nan - val_loss: nan
# Epoch 8/25
# 15/15 [==============================] - 2s 169ms/step - loss: nan - val_loss: nan
# Epoch 9/25
# 15/15 [==============================] - 3s 178ms/step - loss: nan - val_loss: nan
# Epoch 10/25
# 15/15 [==============================] - 3s 173ms/step - loss: nan - val_loss: nan
# Epoch 11/25
# 15/15 [==============================] - 3s 198ms/step - loss: nan - val_loss: nan
# Epoch 12/25
# 15/15 [==============================] - 5s 320ms/step - loss: nan - val_loss: nan
# Epoch 13/25
# 15/15 [==============================] - 3s 176ms/step - loss: nan - val_loss: nan
# Epoch 14/25
# 15/15 [==============================] - 3s 174ms/step - loss: nan - val_loss: nan
# Epoch 15/25
# 15/15 [==============================] - 2s 171ms/step - loss: nan - val_loss: nan
# Epoch 16/25
# 15/15 [==============================] - 3s 196ms/step - loss: nan - val_loss: nan
# Epoch 17/25
# 15/15 [==============================] - 3s 205ms/step - loss: nan - val_loss: nan
# Epoch 18/25
# 15/15 [==============================] - 4s 262ms/step - loss: nan - val_loss: nan
# Epoch 19/25
# 15/15 [==============================] - 3s 171ms/step - loss: nan - val_loss: nan
# Epoch 20/25
# 15/15 [==============================] - 2s 170ms/step - loss: nan - val_loss: nan
# Epoch 21/25
# 15/15 [==============================] - 3s 185ms/step - loss: nan - val_loss: nan
# Epoch 22/25
# 15/15 [==============================] - 3s 200ms/step - loss: nan - val_loss: nan
# Epoch 23/25
# 15/15 [==============================] - 3s 207ms/step - loss: nan - val_loss: nan
# Epoch 24/25
# 15/15 [==============================] - 2s 171ms/step - loss: nan - val_loss: nan
# Epoch 25/25
# 15/15 [==============================] - 3s 173ms/step - loss: nan - val_loss: nan

# %%
test[20]['input']
# Out:
# 'dialogue: Casey Bowman Casey Bowman is a highly skilled ninja who grew up in a traditional ninja family. question: How does Casey Bowman view the outside world? response: No mention. question: How does Casey Bowman maintain his ninja skills? response: Hones skills to perfection. question: How does Casey Bowman feel about his ninja duties? '

# %%
encoded_query = t5_tokenizer(test[20]['input'],
                         return_tensors='tf', padding='max_length', truncation=True, max_length=512)
input_ids = encoded_query["input_ids"]
attention_mask = encoded_query["attention_mask"]
generated_answer = model.generate(input_ids)
t5_tokenizer.decode(generated_answer.numpy()[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/tf_utils.py:838: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# '<pad> response: No mention.</s>'

# %%
test[13]['input']
# Out:
# 'dialogue: Arinon the Bold Arinon is a valiant knight, known for his bravery and unwavering sense of justice. He was born in a small village, but always dreamed of being a knight. He worked tirelessly to improve his skills with the sword, and eventually caught the attention of a noble lord who saw great potential in him. Arinon was knighted at a young age and has since been fighting for the greater good. question: Have you ever tasted the local ale at The Rusty Tankard Inn? '

# %%
encoded_query = t5_tokenizer(test[13]['input'],
                         return_tensors='tf', padding='max_length', truncation=True, max_length=512)
input_ids = encoded_query["input_ids"]
attention_mask = encoded_query["attention_mask"]
generated_answer = model.generate(input_ids)
t5_tokenizer.decode(generated_answer.numpy()[0])
# Out:
# '<pad>response: Arinon the Bold is a knight, known for his bravery and'

# %%
test[13]['response']
# Out:
# "response: I'm afraid I can't say I have. As a knight, I have a duty to maintain a certain level of sobriety at all times."

# %%
sentence_encoder_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
os.environ["TFHUB_MODEL_LOAD_FORMAT"] = "UNCOMPRESSED"
sentence_encoder = hub.load(sentence_encoder_url)
def embed(input):
  return sentence_encoder(input)

# %%
def encode_response(response):
  response_ids = t5_tokenizer(response,
                         return_tensors='tf', padding='max_length', truncation=True, max_length=512)
  response_ids = response_ids["input_ids"]
  return response_ids

# %%
test_inputs = [x['input'] for x in test]
test_labels = [x['response'] for x in test]

# %%
# Source: https://www.tensorflow.org/hub/tutorials/semantic_similarity_with_tf_hub_universal_encoder

sentence_embedding_labels = [embed([x]) for x in test_labels]
encoded_inputs = [encode_response(x) for x in test_inputs]
encoded_predictions = [model.generate(x) for x in encoded_inputs]

# %%
# Source: https://www.tensorflow.org/hub/tutorials/semantic_similarity_with_tf_hub_universal_encoder

decoded_predictions = [t5_tokenizer.decode(x.numpy()[0]) for x in encoded_predictions]
decoded_predictions = [x.replace("<pad>", "").replace("</s>", "") for x in decoded_predictions]
sentence_embedding_predictions = [encode_response([x]) for x in decoded_predictions]

# %%
def calc_similarity(encoded_sentence_1, encoded_sentence_2):
  similarity = np.inner(encoded_sentence_1, encoded_sentence_2)
  return similarity

cosine
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-223d2b411549> in <cell line: 5>()
#       3   return similarity
#       4
# ----> 5 cosine
#
# NameError: name 'cosine' is not defined

# %%
# !pip install -q evaluate
# !pip install rouge_score
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.0 MB/s eta 0:00:00
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.23.5)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.1)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=786b6cb236b269a3efd67f15f8f51617eafda5d68c4046cdf7067462e8d3b930
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
import evaluate
from datasets import load_metric
rouge = load_metric('rouge')
results = rouge.compute(predictions=decoded_predictions, references=test_labels)
print(results)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1344         try:
# -> 1345             return importlib.import_module("." + module_name, self.__name__)
#    1346         except Exception as e:
#
# /usr/lib/python3.10/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/__init__.py in <module>
#      74 from .question_answering import QuestionAnsweringArgumentHandler, QuestionAnsweringPipeline
# ---> 75 from .table_question_answering import TableQuestionAnsweringArgumentHandler, TableQuestionAnsweringPipeline
#      76 from .text2text_generation import SummarizationPipeline, Text2TextGenerationPipeline, TranslationPipeline
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/table_question_answering.py in <module>
#      25     import tensorflow as tf
# ---> 26     import tensorflow_probability as tfp
#      27
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_probability/__init__.py in <module>
#      22 # from tensorflow_probability.google import tfp_google  # DisableOnExport
# ---> 23 from tensorflow_probability.python import *  # pylint: disable=wildcard-import
#      24 from tensorflow_probability.python.version import __version__
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py in <module>
#     137   for pkg_name in _maybe_nonlazy_load:
# --> 138     dir(globals()[pkg_name])  # Forces loading the package from its lazy loader.
#     139
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/internal/lazy_loader.py in __dir__(self)
#      56   def __dir__(self):
# ---> 57     module = self._load()
#      58     return dir(module)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/internal/lazy_loader.py in _load(self)
#      36     if callable(self._on_first_access):
# ---> 37       self._on_first_access()
#      38       self._on_first_access = None
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py in _validate_tf_environment(package)
#      58       distutils.version.LooseVersion(required_tensorflow_version)):
# ---> 59     raise ImportError(
#      60         'This version of TensorFlow Probability requires TensorFlow '
#
# ImportError: This version of TensorFlow Probability requires TensorFlow version >= 2.14; Detected an installation of version 2.12.0. Please upgrade TensorFlow to proceed.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-2072fae1f3c6> in <cell line: 1>()
# ----> 1 import evaluate
#       2 from datasets import load_metric
#       3 rouge = load_metric('rouge')
#       4 results = rouge.compute(predictions=decoded_predictions, references=test_labels)
#       5 print(results)
#
# /usr/local/lib/python3.10/dist-packages/evaluate/__init__.py in <module>
#      27 del version
#      28
# ---> 29 from .evaluation_suite import EvaluationSuite
#      30 from .evaluator import (
#      31     AudioClassificationEvaluator,
#
# /usr/local/lib/python3.10/dist-packages/evaluate/evaluation_suite/__init__.py in <module>
#       8 from datasets.utils.version import Version
#       9
# ---> 10 from ..evaluator import evaluator
#      11 from ..loading import evaluation_module_factory
#      12 from ..utils.logging import get_logger
#
# /usr/local/lib/python3.10/dist-packages/evaluate/evaluator/__init__.py in <module>
#      25 from typing import Dict, List
#      26
# ---> 27 from .audio_classification import AudioClassificationEvaluator
#      28 from .automatic_speech_recognition import AutomaticSpeechRecognitionEvaluator
#      29 from .base import Evaluator
#
# /usr/local/lib/python3.10/dist-packages/evaluate/evaluator/audio_classification.py in <module>
#      21 from ..module import EvaluationModule
#      22 from ..utils.file_utils import add_end_docstrings, add_start_docstrings
# ---> 23 from .base import EVALUATOR_COMPUTE_RETURN_DOCSTRING, EVALUTOR_COMPUTE_START_DOCSTRING, Evaluator
#      24
#      25
#
# /usr/local/lib/python3.10/dist-packages/evaluate/evaluator/base.py in <module>
#      32 try:
#      33     import transformers
# ---> 34     from transformers import Pipeline, pipeline
#      35
#      36     TRANSFORMERS_AVAILABLE = True
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1333             value = self._get_module(name)
#    1334         elif name in self._class_to_module.keys():
# -> 1335             module = self._get_module(self._class_to_module[name])
#    1336             value = getattr(module, name)
#    1337         else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1345             return importlib.import_module("." + module_name, self.__name__)
#    1346         except Exception as e:
# -> 1347             raise RuntimeError(
#    1348                 f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1349                 f" traceback):\n{e}"
#
# RuntimeError: Failed to import transformers.pipelines because of the following error (look up to see its traceback):
# This version of TensorFlow Probability requires TensorFlow version >= 2.14; Detected an installation of version 2.12.0. Please upgrade TensorFlow to proceed.

# %%
model.summary()

# %%
# !pip install -q torchmetrics
from torchmetrics.text.rouge import ROUGEScore
preds = decoded_predictions
target = test_labels
rouge = ROUGEScore()
from pprint import pprint
pprint(rouge(preds, target))
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.2/805.2 kB 6.0 MB/s eta 0:00:00
# {'rouge1_fmeasure': tensor(0.2238),
#  'rouge1_precision': tensor(0.2600),
#  'rouge1_recall': tensor(0.2248),
#  'rouge2_fmeasure': tensor(0.0376),
#  'rouge2_precision': tensor(0.0415),
#  'rouge2_recall': tensor(0.0421),
#  'rougeL_fmeasure': tensor(0.2144),
#  'rougeL_precision': tensor(0.2488),
#  'rougeL_recall': tensor(0.2156),
#  'rougeLsum_fmeasure': tensor(0.2160),
#  'rougeLsum_precision': tensor(0.2514),
#  'rougeLsum_recall': tensor(0.2168)}

# %%
responses_df = pd.DataFrame(data={'inputs': test_inputs, 'labels':test_labels, 'predictions':decoded_predictions})
responses_df
# Out:
#                                                inputs  \
# 0   dialogue: Adalyn the Huntress Adalyn is a fear...
# 1   dialogue: Agent 47 Agent 47 is a genetically e...
# 2   dialogue: Aiden Stone Aiden is a skilled thief...
# 3   dialogue: Alistair the Enchanter Alistair is a...
# 4   dialogue: Althea Althea is a half-elf ranger w...
# ..                                                ...
# 79  dialogue: Vincenzo Vincenzo is a cunning and c...
# 80  dialogue: Wednesday Addams Wednesday Addams is...
# 81  dialogue: Zara the Brave Zara was born in a sm...
# 82  dialogue: Zephyr Zephyr is a mischievous fairy...
# 83  dialogue: Zuko Zuko is a former prince of the ...
#
#                                                labels  \
# 0   response: No, I do not regret any of my hunts....
# 1                    response: Not that I'm aware of.
# 2   response: "The most important lesson I've lear...
# 3   response: Yes, but learned to forgive and move...
# 4   response: (Pauses) There have been a few times...
# ..                                                ...
# 79            response: "Honesty, for fools, not me."
# 80    response: "Justice, important, must be served."
# 81  response: Zara believes that the kingdom is in...
# 82  response: Yes, I have. It was a difficult expe...
# 83  response: My perseverance and determination to...
#
#                                           predictions
# 0    response: I hunt all sorts of animals, especi...
# 1     response: Failure of Agent 47 is not an option.
# 2   response: "I'm an expert in thief and a lot of...
# 3   response: Encountered by Enchanter Alistair th...
# 4   response: (Laughs) I once came across a giant ...
# ..                                                ...
# 79   response: "Honor, honesty, sans getting caught."
# 80       response: "Justice, not important, love is."
# 81  response: Zara doesn't have much free time, bu...
# 82  response: I had a pretty normal childhood, but...
# 83       response: I like to fire and fire in nature.
#
# [84 rows x 3 columns]

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
responses_df.to_csv('drive/My Drive/t5_concat_dialogue.csv')
